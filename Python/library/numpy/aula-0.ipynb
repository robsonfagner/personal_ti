# %%
import numpy as np

# %%
a = [1,2,3,4,5]
type(a)
# Out:
# list

# %%
b = np.array([1,2,3,4,5])
type(b)
# Out:
# numpy.ndarray

# %% [markdown]
# Segundo tipo de Import

# %%
from numpy import *

# %%
array([9,8,7])

# %%
pi

# %% [markdown]
# Vetores

# %%
e1 = (1,0)

# %%
e2 = (0,1)
